# %% [markdown]
# <a href="https://colab.research.google.com/github/rumcrush/cakd3/blob/main/0713_%EC%9B%B9%ED%81%AC%EB%A1%A4%EB%A7%81_%EA%B5%AC%EA%B8%80%ED%94%8C%EB%A0%88%EC%9D%B4%20%ED%81%AC%EB%A1%A4%EB%A7%81%20%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 과제: urllib+bs4 조합으로 다음을 수행하세요
# Q. 'https://www.dataq.or.kr/www/sub/a_07.do'사이트에서 필요한 정보를 가져와서 출력

# %%
from urllib import request as req
from bs4 import BeautifulSoup
import re

res = req.urlopen('https://www.dataq.or.kr/www/sub/a_07.do')
bs = BeautifulSoup(res,'html.parser')

contents = bs.find('div')

for child in contents.children:
    print(child)

#전처리 필요 효율성 매우 낮음. 이건 아닌 것 같다
# Out:
# <div id="header">
# <!-- sub menu -->
# <div class="gnb" id="gnb">
# <div class="gnb-header">
# <div class="container">
# <div class="row">
# <div class="col-sm text-left">
# <a class="gnb-brand" href="/www">
# <img src="/www/css/layout/comm/sm_logo.png" title="데이터자격시험"/>
# </a>
# </div>
# <div class="col-sm text-right">
# <a class="gnb-text" href="javascript:siteFn.fnJoin();">회원가입</a>
# <a class="gnb-text" href="/www/accounts/login.do"><i aria-hidden="true" class="fa fa-sign-in"></i> 로그인</a>
# </div>
# </div>
# </div>
# </div>
# <nav class="navbar navbar-expand-md navbar-light">
# <div class="container">
# <button aria-controls="navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="navbar">
# <!--
# 				<a class="navbar-brand d-none d-lg-block" href="/www">
# ...

# %%
# 과제(자바스크립트 사용)
# Q. 한빛 네트워크 로그인 후 공지사항 가져와서 출력하기
# https://www.hanbit.co.kr/support/help_info.html

# %%
import time
from selenium import webdriver


driver = webdriver.Chrome("/Users/chuka/Desktop/cakd3/tool/chromedriver")

url = 'https://www.hanbit.co.kr/support/help_info.html'
driver.get(url)

pages = driver.execute_script('return document.getElementsByClassName("notice")')

for p in pages:
    print(p.text)
# Out:
# 공지사항
# 더보기
# 코로나19 확산 방지를 위한 재택 근무 안내(7월 12...
# 2021.07.09
# 택배사 파업으로 인한 배송 지연 안내
# 2021.06.15
# 한빛출판네트워크 저작물에 대한 온라인 매체 이용 규...
# 2021.05.17
# 설 연휴로 인한 배송 안내(2월 5일 오전 12시 택배마감...
# 2021.02.03

# %%
# 과제
# Q. 네이버 로그인 후 메일 목록 10개 가져오기(execute_script 사용)

# %%
pip install pyperclip
# Out:
# ...
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=bf499809a35dc4def875c435522244a0a53d1eb711f572e124052a6c54d1039f
#   Stored in directory: /Users/chuka/Library/Caches/pip/wheels/7f/1a/65/84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built pyperclip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pyperclip
import time

driver = webdriver.Chrome("https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com")

driver.get('https://mail.naver.com/')

driver.find_element_by_name('id').click() #아이디 입력창
pyperclip.copy('chihayaburu')
driver.find_element_by_name('id').send_keys(Keys.CONTROL,'v') #아이디 복붙

driver.find_element_by_name('pw').click() #비번 입력창
pyperclip.copy('samt2015')
driver.find_element_by_name('pw').send_keys(Keys.CONTROL,'v') #비번 복붙
time.sleep(3)

driver.find_element_by_id('log.login').click() #로그인 창 클릭

#실패! pyperclip이 안 됨
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/common/service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# /opt/anaconda3/lib/python3.8/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ...

# %%
import time
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome("/Users/chuka/Desktop/cakd3/tool/chromedriver")
driver.get('https://www.naver.com/')

driver.find_element_by_class_name('link_login').click()
time.sleep(2)

driver.execute_script("document.getElementById('id').value = '아이디'")
time.sleep(2)

driver.execute_script("document.getElementById('pw').value = '비밀번호'")
time.sleep(2)


driver.find_element_by_id('log.login').click()
time.sleep(2)

driver.find_element_by_css_selector('#NM_FAVORITE > div.group_nav > ul.list_nav.type_fix > li:nth-child(1) > a').click()
time.sleep(2)

title1 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[1]/div/div[2]/a[1]/span/strong')

title2 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[2]/div/div[2]/a[1]/span/strong')

title3 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[3]/div/div[2]/a[1]/span/strong')

title4 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[4]/div/div[2]/a[1]/span/strong')

title5 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[5]/div/div[2]/a[1]/span/strong')

title6 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[6]/div/div[2]/a[1]/span/strong')

title7 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[7]/div/div[2]/a[1]/span/strong')

title8 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[8]/div/div[2]/a[1]/span/strong')

title9 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[9]/div/div[2]/a[1]/span/strong')

title10 = driver.find_element_by_xpath('//*[@id="list_for_view"]/ol/li[10]/div/div[2]/a[1]/span/strong')


print(title1.text)
print(title2.text)
print(title3.text)
print(title4.text)
print(title5.text)
print(title6.text)
print(title7.text)
print(title8.text)
print(title9.text)
print(title10.text)
# Out:
# [네이버페이] 결제하신 내역을 안내해드립니다.
# [뉴스레터] 투자심사위원회 부결 원인 파악하기
# (광고) 창업을 위한 5월 프로모션!
# [뉴스레터] 스타트업 사업아이템을 심사하면서 느낀 점
# 안녕하세요. 네이버 고객센터입니다.
# [네이버페이] 결제하신 내역을 안내해드립니다.
# [네이버페이] 결제하신 내역을 안내해드립니다.
# [네이버페이] 결제하신 내역을 안내해드립니다.
# 안녕하세요. 네이버 고객센터입니다.
# [뉴스레터] 예비 창업자를 위한 기본 개발 지식

# %%
# 과제
# Q. 할인된 가격이 적용되는 영화만 출력(할인 전 가격, 할인 후 가격, 링크)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from bs4 import BeautifulSoup

driver = webdriver.Chrome("/Users/chuka/Desktop/cakd3/tool/chromedriver")
driver.maximize_window()

url = 'https://play.google.com/store/movies/top'
driver.get(url)


import time
interval = 2

prev_height = driver.execute_script('return document.body.scrollHeight')

while True:
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(interval)
    curr_height = driver.execute_script('return document.body.scrollHeight')
    if curr_height == prev_height:
        break
    else:
        prev_height = curr_height


bs = BeautifulSoup(driver.page_source)
data = bs.select("SUZt4c.djCuy > span")

##여기서 어떻게 하지?

# %% [markdown]
# 0713 일지
# 1. 크롤링을 4일에 걸쳐 배웠고 드디어 웹페이지는 긁어올 수 있는 수준이 됐다
# 2. 비교를 위해서 한국웹고 일본웹을 긁어봤다. 한국웹이 기능이 화려해서 그런가 좀 더 복잡한 것 같았다.
# 3. 크롤링을 더 연습해야 겠단 생각이 많이든다. 웹이나 비정형데이터에 진짜 날것의 정보들이 많은데 사회 현상이나 원인을 파악하는데 무척 도운되는 살아있는 정보가 될 것 같다. 당장 마케팅 실행 후 설문조사는 10통 얻기 힘든데 키워드만 잘 잡으면 좋은 의견이던 나쁜 의견이던 싹 긁어올 수 있는 곳이 웹이니까
# 4. 공공데이터 크롤링을 좀 더 익숙하게 한다면 내가 사는 동네에 대한 데이터 분석도 해보고 싶다. 동네를 좀 더 좋게 만드는 마을가꾸기 사업에 활용할 수 있지 않을까 싶다.
